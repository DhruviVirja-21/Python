# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 5</b></center>
# <center><b><h3>Roll No.:498</b></center>
# <center><b><h3>Name:Virja Dhruvi</b></center>
# <pre>

# %% [markdown]
# ### 1) Character Category Counter
# **Problem:** Count uppercase, lowercase, digits, and special characters in a string.
#
# **Sample Inputs & Outputs:**
# - Input: `Python3@Lab` → Uppercase: 2, Lowercase: 7, Digits: 1, Special: 1
# - Input: `HELLO123` → Uppercase: 5, Lowercase: 0, Digits: 3, Special: 0
# - Input: `hi@#9` → Uppercase: 0, Lowercase: 2, Digits: 1, Special: 2

# %%
s="Python3@Lab"
upper=0
lower=0
digit=0
special=0
for  i in s:
    if(i.isupper()):
        upper+=1
    elif(i.islower()):
        lower+=1
    elif(i.isdigit()):
        digit+=1
    else:
        special+=1
print(f"uppercase={upper},lowercase={lower},digit={digit},special={special}")
# Out:
# uppercase=2,lowercase=7,digit=1,special=1

# %% [markdown]
# ### 2) Reverse Each Word
# - Input: `Python is Easy` → `nohtyP si ysaE`
# - Input: `Hello World` → `olleH dlroW`
# - Input: `Learn Python Fast` → `nraeL nohtyP tsaF`

# %%
s=input("Enter a String")
l=s.split(" ")
rev=""
for i in l:
    rev=rev+(i[::-1])+" "
print(rev)
# Out:
# Enter a StringDhruvi Virja
# ivurhD ajriV

# %% [markdown]
# ### 3) Case Pattern Identifier
# - `PYTHON` → Uppercase
# - `python` → Lowercase
# - `Python Programming` → Title Case

# %%
s=input("Enter a String")
if(s.isupper()):print("UPPERCASE")
elif(s.islower()):print("LOWERCASE")
elif(s.istitle()):print("Title Case")
# Out:
# Enter a StringDhruvi Virja
# Title Case

# %% [markdown]
# ### 4) First and Last Occurrence Finder
# - `programming`, `g` → First:3 Last:10
# - `banana`, `a` → First:1 Last:5
# - `hello`, `z` → Not found

# %%
s=input("Enter a String")
c=input("Enter letter")

f1=s.find(c)
f2=s.rfind(c)
if(f1==-1 and f2==-1):print("Not Found")
else:print(f"Fist={f1},Last={f2}")
# Out:
# Enter a Stringhello
# Enter letterw
# Not Found

# %% [markdown]
# ### 5) Word Frequency Counter (ignore the case)
# - `Python is easy and Python is powerful` → python: 2
# - `Java is popular but java is verbose` → java: 2
# - `C is fast` → c:1

# %%
s=input("Enter a String")
w=input("Enter a word")

print(f"{w}={s.count(w)}")
# Out:
# Enter a StringPython is easy and Python is powerful
# Enter a wordPython
# Python =2

# %% [markdown]
# ### 6) Remove Extra Spaces
# - `  Python   is   fun  ` → `Python is fun`
# - `   Hello   World ` → `Hello World`
# - `NoExtraSpace` → `NoExtraSpace`

# %%
s=input("Enter a String")
ans=""
l=s.split()
for i in l:
    ans=ans+i+" "
print(ans)
# Out:
# Enter a String Python   is   fun
# Python is fun

# %% [markdown]
# ### 7) Prefix and Suffix Removal
# - `unhappy.txt` → `happy`
# - `pretest.py` → `test`
# - `unwanted.doc` → `wanted`

# %%
s1=input("Enter a String")
s2=input("Enter a  Prefix: ")
s3=input("Enter a  Suffix: ")
s=s1.removeprefix(s2).removesuffix(s3)
print(s)
# Out:
# Enter a Stringunhappy.txt
# Enter a  Prefix: un
# Enter a  Suffix: .txt
# happy

# %% [markdown]
# ### 8) Replace Vowels
# - `Programming` → `Pr*gr*mm*ng`
# - `Education` → `*d*c*t**n`
# - `Sky` → `Sky`

# %%
s=input("Enter a String")
ans=''
for d in s:
    i=d.lower()
    if(i=='a' or i=='e' or i=='i' or i=='o' or i=='u'):
        ans=ans+d.replace(i,'*')
    else:ans=ans+d
print(ans)
# Out:
# Enter a StringProgramming
# Pr*gr*mm*ng

# %% [markdown]
# ### 9) String Compression
# - `aaabbcccc` → `a3b2c4`
# - `xxxyyyz` → `x3y3z1`
# - `abcd` → `a1b1c1d1`

# %%
li=input("Enter a String")
c=1
ans=''
for i in range(0,len(li)-1):
    if li[i]==li[i+1]:
        c+=1
    else:
        ans+=li[i]+str(c)
        c=1
ans+=li[i]+str(c)
c=1
ans
# Out:
# Enter a Stringaaabbbccc
# 'a3b3c3'

# %% [markdown]
# ### 10) Toggle Case (without using str.swapcase())
# - `PyThOn` → `pYtHoN`
# - `HELlo` → `helLO`
# - `Python` → `pYTHON`

# %%
s=input("Enter a String")
ans=''
for i in s:
    if(i.islower()):
        ans=ans+i.upper()
    else:
        ans=ans+i.lower()
ans
# Out:
# Enter a StringPyThOn
# 'pYtHoN'

# %% [markdown]
# ### 11) Username Validation
# #### valid username rules:
# 1. only alphabets and digits
# 2. does not start with a digit
# 3. length ≥ 6
#
# - `User123` → Valid
# - `123User` → Invalid
# - `Us@12` → Invalid

# %%
s = input("Enter a username: ")

if len(s) < 6:
    print("Invalid")
elif s[0].isdigit():
    print("Invalid")
elif not s.isalnum():
    print("Invalid")
else:
    print("Valid")
# Out:
# Enter a username:  Us@12
# Invalid

# %% [markdown]
# ### 12) Palindrome Checker (ignore the case)
# - `Madam` → Palindrome
# - `Level` → Palindrome
# - `Python` → Not Palindrome

# %%
str = input("Enter a username: ")
s=str.lower()
if s==s[::-1]:
    print("Palindrome");
else:
    print("Not Palindrome")
# Out:
# Enter a username:  Python
# Not Palindrome

# %% [markdown]
# ### 13) Longest Word Finder
# - `Python programming is interesting` → programming
# - `I love coding` → coding
# - `Data structures and algorithms` → structures

# %%
st = input("Enter a username: ")
s=st.split()
long=s[0]
for i in s:
    if len(i)>len(long):
        long=i
long
# Out:
# Enter a username:  Data structures and algorithms
# 'structures'

# %% [markdown]
# ### 14) Case Conversion
# - `python programming`
#   - Upper: PYTHON PROGRAMMING
#   - Lower: python programming
#   - Title: Python Programming
#   - Capitalize: Python programming

# %%
s = input("Enter a string: ")

print("Upper:", s.upper())
print("Lower:", s.lower())
print("Title:", s.title())
print("Capitalize:", s.capitalize())
# Out:
# Enter a string:  python programming
# Upper: PYTHON PROGRAMMING
# Lower: python programming
# Title: Python Programming
# Capitalize: Python programming

# %% [markdown]
# ### 15) Custom Split
# - `apple,banana,grape`
# - `10|20|30`
# - `A-B-C-D`

# %%
s = input("Enter a string: ")
sep = input("Enter the separator: ")

result = s.split(sep)
print(result)
# Out:
# Enter a string:  A-B-C-D
# Enter the separator:  -
# ['A', 'B', 'C', 'D']
