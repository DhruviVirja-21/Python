# %% [markdown]
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to check whether the given number is positive or negative.

# %%
n=int(input("enter a number"))
if n>0: print("positive")
elif n<0:print("nagative")
else: print("Zero")
# Out:
# enter a number 2
# positive

# %% [markdown]
# ### 02) WAP to check whether the given number is odd or even.

# %%
n=int(input("enter a number"))
if n%2==0:print ("even")
else:print("odd")
# Out:
# enter a number 3
# odd

# %% [markdown]
# ### 03) WAP to find out largest number from given two numbers using simple if and ternary operator.

# %%
n1=int(input("enter a number"))
n2=int(input("enter a number"))
res=n1 if n1>n2 else n2
print(f"{res} is greater ")

if n1>n2:print("n1 is greater")
else:print("n2 is greater")
# Out:
# enter a number 2
# enter a number 3
# 3 is greater
# n2 is greater

# %% [markdown]
# ### 04) WAP to find out largest number from given three numbers.

# %%
n1=int(input("enter a number"))
n2=int(input("enter a number"))
n3=int(input("enter a number"))
res=n1 if n1>n2 and n1>n3 else n2 if n2>n3 else n3
print(f"{res} is greater ")
# Out:
# enter a number 4
# enter a number 3
# enter a number 10
# 10 is greater

# %% [markdown]
# ### 05) WAP to check whether the given year is leap year or not.
# #### [If a year can be divisible by 4 but not divisible by 100 then it is leap year but if it is divisible by 400 then it is leap year]

# %%
n=int(input("enter a number"))
if n%4==0 and n%100!=0 or n%400==0:print("leap year")
else:print("not leap year")
# Out:
# enter a number 2011
# not leap year

# %% [markdown]
# ### 06) WAP in python to display the name of the day according to the number given by the user.

# %%
n=int(input("enter a number"))
match n:
    case 1:print("sunday")
    case 2:print("monday")
    case 3:print("tuseday")
    case 4:print("wednesday")
    case 5:print("thursday")
    case 6:print("friday")
    case 7:print("sasturday")
    case _:print("invalid input")
# Out:
# enter a number 3
# tuseday

# %% [markdown]
# ### 07) WAP to implement simple calculator which performs (add,sub,mul,div) of two no. based on user input.

# %%
n1=int(input("enter a number"))
n2=int(input("enter a number"))
choice=input("Enatr '+','-','*',''/':")
match choice:
    case '+':print(f"{n1}+{n2}={n1+n2}")
    case '-':print(f"{n1}-{n2}={n1-n2}")
    case '*':print(f"{n1}*{n2}={n1*n2}")
    case '/':print(f"{n1}/{n2}={n1/n2}")
# Out:
# enter a number 2
# enter a number 3
# Enatr '+','-','*',''/': +
# 2+3=5

# %% [markdown]
# ### 08) WAP to read marks of five subjects. Calculate percentage and print class accordingly.
# #### Fail below 35
# #### Pass Class between 35 to 45
# #### Second Class
# #### between 45 to 60
# #### First Class between 60 to 70
# #### Distinction if more than 70

# %%
n1=int(input("enter a number"))
n2=int(input("enter a number"))
n3=int(input("enter a number"))
n4=int(input("enter a number"))
n5=int(input("enter a number"))
avg=((n1+n2+n3+n4+n5)/5)*100
if (avg>70):print('Distinction')
elif (avg>60 and avg<70):print('First Class')
elif(avg>45 and avg<60):print('second Class')
elif(avg>35 and avg<45):print('Pass Class')
else:print('Fail')
# Out:
# enter a number 90
# enter a number 90
# enter a number 90
# enter a number 90
# enter a number 90
# Distinction

# %% [markdown]
# ### 09) WAP to find the second largest number among three user input numbers.

# %%
n1=int(input("enter a number"))
n2=int(input("enter a number"))
n3=int(input("enter a number"))
if (n1 > n2 and n1 < n3) or (n1 > n3 and n1 < n2):
    print("n1 is second greatest")
elif (n2 > n1 and n2 < n3) or (n2 > n3 and n2 < n1):
    print("n2 is second greatest")
else:
    print("n3 is second greatest")
# Out:
# enter a number 2
# enter a number 3
# enter a number 4
# n2 is second greatest

# %% [markdown]
# ### 10) WAP to calculate electricity bill based on following criteria. Which takes the unit from the user.
# #### a. First 1 to 50 units – Rs. 2.60/unit
# #### b. Next 50 to 100 units – Rs. 3.25/unit
# #### c. Next 100 to 200 units – Rs. 5.26/unit
# #### d. above 200 units – Rs. 8.45/unit

# %%
units=int(input("Enter total units consumed: "))
bill=0

if units<=50:
    bill=units*2.60

elif units<=100:
    bill=(50*2.60)+((units-50)*3.25)

elif units<=200:
    bill=(50*2.60)+(50*3.25)+((units-100)*5.26)

else:
    bill=(50*2.60)+(50*3.25)+(100*5.26)+((units-200)*8.45)

print("Total Electricity Bill = Rs.", bill)
# Out:
# Enter total units consumed:  230
# Total Electricity Bill = Rs. 1072.0
