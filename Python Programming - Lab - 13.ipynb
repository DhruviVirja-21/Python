# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h3>Roll No.:498</b></center>
# <center><b><h3>Name:Dhruvi Virja</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import Calculater
Calculater.sum(2,3)
Calculater.subtract(3,2)
Calculater.multiplication(2,3)
Calculater.division(2,3)
# Out:
# sum of a and b = 5
# subtract of a and b = 1
# multiplication of a and b = 6
# division of a and b = 0.6666666666666666

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random
s = "HelloWorld"
char = random.choice(s)
print("Random character:", char)
# Out:
# Random character: o

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
li=list(range(101,111))
random.choice(li)
# Out:
# 107

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
random.seed(10)
print("Dice roll:", random.randint(1,6))
# Out:
# Dice roll: 5

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
import random
li = [i for i in range(100,1000) if i % 5 == 0]
print(random.sample(li,3))
# Out:
# [835, 115, 360]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
li = [i for i in range(101)]
print(f'Winner={random.choice(li)}')
print(f'Runner={random.choice(li)}')
# Out:
# Winner=20
# Runner=4

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-03-11 10:45:56.228419

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
now=datetime.datetime.now()
output=now-datetime.timedelta(weeks=1)
print(output)
# Out:
# 2026-03-04 10:52:50.292464

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
date1 = datetime.date(2023, 1, 1)
date2 =datetime.date(2024, 1, 1)
duration = date2 - date1
print(duration.days)
# Output: 365 days, 0:00:00
# Out:
# 365

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
import datetime

date = input("Enter date (YYYY-MM-DD): ")
d = datetime.datetime.strptime(date, "%Y-%m-%d")
day = d.strftime("%A")
print("Day of the week is:", day)
# Out:
# Enter date (YYYY-MM-DD):  2026-12-21
# Day of the week is: Monday
