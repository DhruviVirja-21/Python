# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 9</b></center>
# <center><b><h3>Roll No :498 </b></center>
# <center><b><h3>Name :Virja Dhruvi </b></center>
# <pre>

# %% [markdown]
# ### 01) Write a function to calculate BMI given mass and height. (BMI = mass/h**2)

# %%
def BMI(m,h):
 bmi=m/(h**2) 
 print(bmi)
m=int(input("entre Mass:"))
h=int(input("enter Hihgt"))
BMI(m,h)
# Out:
# entre Mass: 2
# enter Hihgt 2
# 0.5

# %% [markdown]
# ### 02) Write a function that add first n numbers.

# %%
def sumofN(i):
    sum=0
    for i in range(1,i+1):
        sum=sum+i
    print(sum)
n=int(input("enter N:"))
sumofN(n)
# Out:
# enter N: 5
# 15

# %% [markdown]
# ### 03) Write a function that returns 1 if the given number is Prime or 0 otherwise.

# %%
def primeornot(n):
    for i in range(2,n):
        if(n%i==0):
            return 1;
        else:
            return 0;
n=int(input("enter N:"))
primeornot(n)
# Out:
# enter N: 24
# 1

# %% [markdown]
# ### 04) Write a function that returns the list of Prime numbers between given two numbers.

# %%
def prime(r1, r2):
    li = []
    for i in range(r1, r2 + 1):
        for j in range(2,i):
            if(i%j==0):
                break
        else:
                li.append(i)
           
    print(li)

prime(5, 10)
# Out:
# [5, 7]

# %% [markdown]
# ### 05) Write a function that returns True if the given string is Palindrome or False otherwise.

# %%
def palindrom(s):
    return s == s[::-1]

s = input("enter string: ")
print(palindrom(s))
# Out:
# enter string:  dhruvi
# False

# %% [markdown]
# ### 06) Write a function that returns the sum of all the elements of the list.

# %%
def listsum(li):
    print(sum(li))
    
li=list(map(int,input("enter a list:").split()))
listsum(li)
# Out:
# enter a list: 1 2 3 4 5
# 15

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %% [markdown]
# ### 07) Write a function to calculate the sum of the first element of each tuples inside the list.

# %%
def sumof1(l1):
    print(sum(t[0] for t in l1))

length = int(input("Enter lenght"))
l1=[]
for i in range(0,length):
    t1=tuple(map(int,input("Enter values sep by space").split()))
    l1.append(t1)
sumof1(l1)
# Out:
# Enter lenght 3
# Enter values sep by space 2 3 4
# Enter values sep by space 1 2 3
# Enter values sep by space 4 5 6
# 7

# %% [markdown]
# ### 08) Write a recursive function to find nth term of Fibonacci Series.

# %%
def fibonacci(n):
   if (n==0):
       return 0
   elif(n==1):
       return 1
   else:
       return fibonacci(n-1)+fibonacci(n-2)
fibonacci(10)
# Out:
# 55

# %% [markdown]
# ### 09) Write a function to get the name of the student based on the given rollno.
# #### Example: Given dict1 = {101:'Ajay', 102:'Rahul', 103:'Jay', 104:'Pooja'} find name of student whose rollno = 103

# %%
def student(d1,roll):
     return d1.get(roll, "Roll number not found")

l1=list(map(int, input("Enter list keys: ").split()))
l2=list(input("Enter list valuse: ").split())
d1=dict(zip(l1,l2))
roll=int(input("enter rollno:"))
student(d1,roll)
# Out:
# Enter list keys:  101 102 103 104
# Enter list valuse:  ajay rahul jay pooja
# enter rollno: 103
# 'jay'

# %% [markdown]
# ### 10) Write a function to get the sum of the scores ending with zero.
# #### Example : scores = [200, 456, 300, 100, 234, 678]
# #### Ans = 200 + 300 + 100 = 600

# %%
def sumofendzero(li):
    print(sum([i for i in li if i%10==0]))
li=list(map(int,input("enter a list:").split()))
sumofendzero(li)
# Out:
# enter a list: 200 300 456 100 234 678
# 600

# %% [markdown]
# ### 11) Write a function to invert a given Dictionary.
# #### hint: keys to values & values to keys
# #### Before : {'a': 10, 'b':20, 'c':30, 'd':40}
# #### After : {10:'a', 20:'b', 30:'c', 40:'d'}

# %%
def invert(d1,d2):
    for k,v in d1.items():
        d2[v]=k
    print(d2)    
    
   
l1=list(input("Enter list keys: ").split()) 
l2=list(map(int, input("Enter list  valuse: ").split()))
d1=dict(zip(l1,l2))  
d2={}
invert(d1,d2)
# Out:
# Enter list keys: a b c d
# Enter list  valuse: 10 20 30 40
# {10: 'a', 20: 'b', 30: 'c', 40: 'd'}

# %% [markdown]
# ### 12) Write a function that returns the number of uppercase and lowercase letters in the given string.
# #### example : Input : s1 = AbcDEfgh ,Ouptput : no_upper = 3, no_lower = 5

# %%
def upperlower(s):
    no_lower=0
    no_upper=0
    for i in s:
        if i.islower():
            no_lower+=1
        else:
            no_upper+=1
 
    print(f"no_upper={no_upper}, no_lower={ no_lower}")
s=input("enter a string:")
upperlower(s)
# Out:
# enter a string:AbcDEfgh
# no_upper=3, no_lower=5

# %% [markdown]
# ### 13) Write a lambda function to get smallest number from the given two numbers.

# %%
smallest=lambda x,y:x if x<y else y
print(f"smallest:{smallest(10,20)}")
# Out:
# smallest:10

# %% [markdown]
# ### 14) For the given list of names of students, extract the names having more that 7 characters. Use filter().

# %%
def lenmorerthen7(l):
    if len(l)>7:
        return l
li=list(input("enter a list:").split())
list(filter(lenmorerthen7,li))
# Out:
# enter a list:kavu devanshi pragati dhruvi
# ['devanshi']

# %% [markdown]
# ### 15) For the given list of names of students, convert the first letter of all the names into uppercase. use map().

# %%
li=list(input("enter a list:").split())
list(map(lambda x:x.replace(x[0],x[0].upper()),li))
# Out:
# enter a list:kaveri dhruvi devanshi pragati
# ['Kaveri', 'Dhruvi', 'Devanshi', 'Pragati']

# %% [markdown]
# ### 16) Write udfs to call the functions with following types of arguments:
# 1. Positional Arguments
# 2. Keyword Arguments
# 3. Default Arguments
# 4. Variable Legngth Positional(*args) & variable length Keyword Arguments (**kwargs)
# 5. Keyword-Only & Positional Only Arguments

# %%
def positional(a,b):
    print(a,b)
positional(10,20)
# Out:
# 10 20

# %%
def keyword(a,b):
    print(a,b)
keyword(a=2,b=3)
# Out:
# 2 3

# %%
def defult(a,b,c=1):
    print (a,b,c)
defult(1,2)
# Out:
# 1 2 1

# %%
def funVLP(*args):
    print(args)
funVLP(1,2,4)
# Out:
# (1, 2, 4)

# %%
def funVKP(**args):
    print(args)
funVKP(a=1,b=2,c=4)
# Out:
# {'a': 1, 'b': 2, 'c': 4}

# %%
def onlykey(*,a,b):
    print(a,b)
onlykey(a=10,b=20)
# Out:
# 10 20

# %%
def onlypositional(a,b,/):
    print(a,b)
onlypositional(10,20)
# Out:
# 10 20
