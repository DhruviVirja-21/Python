# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
# <center><b><h3>Roll No : 498</b></center>
# <center><b><h3>Name :Virja Dhruvi </b></center>
# <pre>

# %% [markdown]
# # Progrmas based on Python Data Structure + UDF + File Handling

# %% [markdown]
# ### Practical 1: Count Lines, Words and Characters
#
# **Problem Definition:**
# Write a Python program to read text from a file and count the total number of lines, words, and characters. The result should be written to an output file.

# %%
fp=open("abc.txt","r")
data=fp.read()
chars=0
for ch in data:
    if ch != " " and ch != "\n":
        chars += 1
word=len(data.split())
line=data.count("\n")+1
f=open("output.txt","w")
f.write("output file for read line,words,char from abc.txt file")
f.writelines(f"\nchars={chars},word={word},line={line}")
fp.close()
f.close()

# %% [markdown]
# ### Practical 2: Search a Word in a File
#
# **Problem Definition:**
# Write a Python program to search a given word in a text file and count its occurrences. Store the result in an output file.

# %%
search=input("Enter word:")
fp=open("abc.txt","r")
data=fp.read().count(search)
fp.close()
f=open("output.txt","w")
f.writelines(f"occurrences of {search}={data}")
print("store successfully")
f.close()
# Out:
# Enter word: virja
# store successfully

# %% [markdown]
# ### Practical 3: Student Marks and Average
#
# **Problem Definition:**
# Write a Python program to read roll number, name, and marks of students from a file. Store marks in a list, calculate the average using a user-defined function, and write student details along with average marks to an output file.

# %%
def calculate_average(marks):
    if len(marks) == 0:
        return 0
    return sum(marks) / len(marks)

f1 = open("stuinfo.txt", "r")
for line in f1:
    data = line.split()  
    
    roll_no = data[0]
    name = data[1]
    marks = list(map(int, data[2:]))

    avg = calculate_average(marks)

    f2 = open("output.txt", "a")
    f2.write(f"Roll No:{roll_no},Name:{name},Marks:{marks},Average:{avg:.2f}\n")
    f2.close()

print("Student details and averages have been written to output.txt")

f1.close()
# Out:
# Student details and averages have been written to output.txt

# %% [markdown]
# ### Practical 4: Maximum and Minimum using Tuple
#
# **Problem Definition:**
# Write a Python program to read numbers from a file, store them in a tuple, and find the maximum and minimum values. Write the result to an output file.

# %%
with open("primenumbers.txt", "r") as f:
    data = f.read().split()
    
numbers = tuple(map(int, data))

maximum = max(numbers)
minimum = min(numbers)

with open("output.txt", "w") as f:
    f.write("Numbers: " + str(numbers) + "\n")
    f.write("Maximum value: " + str(maximum) + "\n")
    f.write("Minimum value: " + str(minimum) + "\n")

print("Maximum and Minimum values written to output file.")
# Out:
# Maximum and Minimum values written to output file.

# %% [markdown]
# ### Practical 5: Remove Duplicate Words using Set
#
# **Problem Definition:**
# Write a Python program to read words from a file and remove duplicate words using a set. Store the unique words in an output file.

# %%
f1 = open("input.txt", "r")
words= f1.read().split()
unique_words = set(words)

f2 = open("output.txt", "w")
for word in unique_words:
    f2.write(word + " ")

print("Duplicate words removed and stored in output.txt")

f1.close()
f2.close()
# Out:
# Duplicate words removed and stored in output.txt

# %% [markdown]
# ### Practical 6: Word Frequency using Dictionary
#
# **Problem Definition:**
# Write a Python program to count the frequency of each word in a text file using a dictionary and write the result to an output file.

# %%
word_freq={}
f1 = open("input.txt", "r")
words= f1.read().split()
for word in words:
    word_freq[word] = words.count(word)
f1.close()
f2 = open("output.txt", "a")
for word, freq in word_freq.items():
        f2.write(f"{word} : {freq}\n")
print(" frequency of words stored in output.txt")    
f2.close()
# Out:
#  frequency of words stored in output.txt

# %% [markdown]
# ### Practical 7: Student Result and Grade Calculation
#
# **Problem Definition:**
# Write a Python program to read roll number, name, and marks of students from a file. Use a user-defined function to determine grade (A/B/C/Fail) and write the student result to an output file.
#
# **Grade Criteria:**
# - Marks ≥ 75 : Grade A
# - Marks ≥ 60 : Grade B
# - Marks ≥ 40 : Grade C
# - Marks < 40 : Fail

# %%
def calculate_Grade(marks):
    avg=sum(marks) / len(marks)
    if(avg>=75):return "Grade A"
    elif (75>avg>=60):return "Grade B"
    elif(60>avg>=40):return"Grade C"
    else:return"Fail"

f1 = open("stuinfo.txt", "r")
for line in f1:
    data = line.split()  
    
    roll_no = data[0]
    name = data[1]
    marks = list(map(int, data[2:]))

    Grade= calculate_Grade(marks)

    f2 = open("output.txt", "a")
    f2.write(f"Roll No:{roll_no},Name:{name},Marks:{marks},Grade:{Grade}\n")
    f2.close()

print("Student details and Grade have been written to output.txt")

f1.close()
# Out:
# Student details and Grade have been written to output.txt
